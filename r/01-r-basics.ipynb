# %% [markdown]
# # R Fundamentals
#
# ## What you'll learn
# - What R is and why it's used for data analysis
# - Variables, data types, and basic operations
# - Vectors and data frames — R's core data structures
# - The tidyverse: a modern toolkit for working with data
# - How to load, explore, and transform a real dataset
#
# ## Prerequisites
# - The `codingcs` environment is activated (see SETUP.md)
# - You can open and run Jupyter notebooks in VS Code

# %% [markdown]
# ## What is R?
#
# R is a programming language designed for statistics and data analysis. It was created by statisticians, so it has built-in support for things like calculating averages, running regressions, and making charts. R is one of the two most popular languages for data work (the other being Python — you'll learn that too).
#
# R is especially popular in academia, healthcare, finance, and any field that relies on statistics.

# %% [markdown]
# ## Variables and Assignment
#
# A **variable** is a name that stores a value. Think of it like a labeled box — you put something inside and can refer to it later by name.
#
# In R, the standard way to assign a value to a variable is with the arrow `<-`. You can also use `=`, but `<-` is the R convention.

# %%
# Assign the value 10 to a variable called x
x <- 10

# Print the value of x (in Jupyter, just typing the variable name prints it)
x

# %%
# You can use = too, but <- is preferred in R
y = 20
y

# %%
# Variables can store text (called "character strings" in R)
greeting <- "Hello, world!"
greeting

# %% [markdown]
# ## Data Types
#
# Every value in R has a **type**. The three most common types are:
#
# | Type | What it stores | Examples |
# |------|---------------|----------|
# | `numeric` | Numbers (with or without decimals) | `42`, `3.14`, `-7` |
# | `character` | Text (always in quotes) | `"hello"`, `"R is fun"` |
# | `logical` | True/false values | `TRUE`, `FALSE` |
#
# Use `class()` to check what type a value is.

# %%
class(42)

# %%
class("hello")

# %%
class(TRUE)

# %% [markdown]
# ## Basic Arithmetic
#
# R works like a calculator. The standard math operators are:
#
# | Operator | Meaning | Example |
# |----------|---------|--------|
# | `+` | Addition | `5 + 3` → 8 |
# | `-` | Subtraction | `10 - 4` → 6 |
# | `*` | Multiplication | `3 * 7` → 21 |
# | `/` | Division | `15 / 4` → 3.75 |
# | `^` | Exponent (power) | `2 ^ 3` → 8 |
# | `%%` | Modulo (remainder) | `10 %% 3` → 1 |

# %%
# Try some arithmetic
5 + 3

# %%
2 ^ 10

# %%
# You can use variables in calculations
price <- 49.99
tax_rate <- 0.07
total <- price * (1 + tax_rate)
total

# %% [markdown]
# ## Vectors
#
# A **vector** is R's most basic data structure — it's an ordered list of values of the same type. You create a vector with the `c()` function (short for "combine" or "concatenate").
#
# **Important:** R uses 1-based indexing. The first element is at position 1 (not 0 like in Python).

# %%
# Create a vector of temperatures
temps <- c(72, 68, 75, 80, 77, 69, 73)
temps

# %%
# Access individual elements (1-based!)
temps[1]   # first element

# %%
temps[3]   # third element

# %%
# Get a range of elements
temps[2:4]   # elements 2 through 4

# %% [markdown]
# ### Vectorized Operations
#
# One of R's strengths is that math operations work on entire vectors at once — no need to loop through each element.

# %%
# Convert all temperatures from Fahrenheit to Celsius
(temps - 32) * 5 / 9

# %%
# Useful built-in functions for vectors
length(temps)   # how many elements

# %%
sum(temps)      # add them all up

# %%
mean(temps)     # average

# %%
min(temps)      # smallest value

# %%
max(temps)      # largest value

# %% [markdown]
# ## Character Strings
#
# Text values in R are called **character strings** (or just "strings"). Here are some useful functions for working with text.

# %%
name <- "data science"

# Number of characters
nchar(name)

# %%
toupper(name)   # UPPERCASE

# %%
tolower("HELLO")   # lowercase

# %%
# paste() joins strings together
paste("Hello", "World")

# %%
# paste0() joins without a space
paste0("file_", 1:3, ".csv")

# %%
# substr() extracts part of a string: substr(text, start, stop)
substr("2024-01-15", 1, 4)   # extract the year

# %% [markdown]
# ## Logical Comparisons and Filtering
#
# **Comparison operators** return `TRUE` or `FALSE`:
#
# | Operator | Meaning |
# |----------|---------|
# | `==` | Equal to |
# | `!=` | Not equal to |
# | `<` | Less than |
# | `>` | Greater than |
# | `<=` | Less than or equal to |
# | `>=` | Greater than or equal to |
#
# You can use these to filter vectors.

# %%
# Which temperatures are above 74?
temps > 74

# %%
# Use the logical vector to filter: keep only values where the condition is TRUE
temps[temps > 74]

# %%
# How many days were above 74?
sum(temps > 74)

# %% [markdown]
# ## Data Frames
#
# A **data frame** is R's version of a spreadsheet — a table with rows and columns. Each column is a vector, and columns can have different types (one column might be numbers, another text).
#
# You create one with `data.frame()` and access columns with `$`.

# %%
# Create a small data frame
students <- data.frame(
  name = c("Alice", "Bob", "Carlos"),
  grade = c(92, 85, 78),
  passed = c(TRUE, TRUE, TRUE)
)

students

# %%
# Access a single column with $
students$grade

# %%
# Calculate the average grade
mean(students$grade)

# %% [markdown]
# ## Packages: Installing vs Loading
#
# A **package** is a collection of functions that someone has written and shared. R comes with many built-in functions, but packages extend what R can do.
#
# There are two steps to using a package:
# 1. **Install** it (download it to your computer) — you only do this once
# 2. **Load** it with `library()` — you do this every time you start a new session
#
# Since we set up our environment with micromamba, all the packages we need are already installed. We just need to load them.

# %% [markdown]
# ## The Tidyverse
#
# The **tidyverse** is a collection of R packages designed for data science. When you load it, you get several packages at once:
#
# - **dplyr** — tools for transforming data (filter, sort, summarize)
# - **ggplot2** — tools for making charts and plots
# - **readr** — tools for reading data files (like CSVs)
# - **tidyr** — tools for reshaping data
# - and several more
#
# Loading `tidyverse` is like opening a toolbox — you get access to all these tools at once.

# %%
# Load the tidyverse (you'll see a message listing what was loaded)
library(tidyverse)

# %% [markdown]
# ## The Pipe Operator: `|>`
#
# The **pipe** takes the result of whatever is on its left and passes it as the first argument to the function on its right. Read it as **"and then"**.
#
# R has two pipe operators:
# - `|>` — the built-in pipe (R 4.1+)
# - `%>%` — the tidyverse pipe (from the `magrittr` package)
#
# They do the same thing. We'll use `|>` since it's built in.
#
# Without the pipe, you nest function calls inside each other, which is hard to read:
# ```r
# round(mean(c(1, 2, 3, 4, 5)), 2)
# ```
#
# With the pipe, you read left to right:
# ```r
# c(1, 2, 3, 4, 5) |> mean() |> round(2)
# ```

# %%
# Without pipe (read inside-out)
round(mean(c(12.3, 45.6, 78.9)), 1)

# %%
# With pipe (read left to right: create vector, THEN take mean, THEN round)
c(12.3, 45.6, 78.9) |> mean() |> round(1)

# %% [markdown]
# ## Reading a CSV File
#
# Now let's work with real data. The `readr` package (part of tidyverse) provides `read_csv()` to load CSV files into a data frame.
#
# We'll load the employees dataset included in this repository.

# %%
employees <- read_csv("../data/employees.csv")
employees

# %% [markdown]
# ## Exploring a Dataset
#
# When you first load data, you'll want to look at it from different angles. Here are the essential exploration functions.

# %%
# First 6 rows
head(employees)

# %%
# Compact summary of the structure
glimpse(employees)

# %%
# Statistical summary of each column
summary(employees)

# %%
# Dimensions
nrow(employees)   # number of rows

# %%
ncol(employees)   # number of columns

# %%
# Column names
names(employees)

# %% [markdown]
# ## dplyr: Transforming Data
#
# The `dplyr` package gives you five main "verbs" for working with data. Each one does one thing:
#
# | Verb | What it does | SQL equivalent |
# |------|-------------|----------------|
# | `select()` | Pick columns | SELECT |
# | `filter()` | Pick rows based on conditions | WHERE |
# | `mutate()` | Create or modify columns | (computed columns) |
# | `arrange()` | Sort rows | ORDER BY |
# | `summarize()` | Calculate summary statistics | aggregate functions |
#
# You chain them together with the pipe `|>`. Let's try each one.

# %% [markdown]
# ### select() — Choose Columns
#
# `select()` keeps only the columns you name.

# %%
# Keep only name, department, and salary
employees |> select(name, department, salary)

# %%
# Drop a column with a minus sign
employees |> select(-id)

# %% [markdown]
# ### filter() — Choose Rows
#
# `filter()` keeps only the rows where a condition is TRUE.

# %%
# Employees in the Engineering department
employees |> filter(department == "Engineering")

# %%
# Employees earning more than 100,000
employees |> filter(salary > 100000)

# %%
# Combine conditions: Engineering AND salary above 80,000
employees |> filter(department == "Engineering", salary > 80000)

# %% [markdown]
# ### mutate() — Create New Columns
#
# `mutate()` adds new columns (or modifies existing ones) based on calculations.

# %%
# Add a column for monthly salary
employees |> mutate(monthly_salary = salary / 12)

# %%
# Add a column that labels salary level
employees |> mutate(
  salary_level = if_else(salary > 100000, "high", "standard")
)

# %% [markdown]
# ### arrange() — Sort Rows
#
# `arrange()` sorts the data. Use `desc()` for descending order.

# %%
# Sort by salary (lowest first)
employees |> arrange(salary)

# %%
# Sort by salary (highest first)
employees |> arrange(desc(salary))

# %% [markdown]
# ### summarize() + group_by() — Aggregate Data
#
# `summarize()` collapses the data into summary statistics. Combined with `group_by()`, it computes those statistics per group.

# %%
# Overall average salary
employees |> summarize(avg_salary = mean(salary))

# %%
# Average salary BY department
employees |>
  group_by(department) |>
  summarize(
    avg_salary = mean(salary),
    count = n()
  ) |>
  arrange(desc(avg_salary))

# %% [markdown]
# ### Chaining It All Together
#
# The real power comes from chaining multiple verbs with `|>`. Read this as a sentence: "Take employees, **then** filter to Sales and Marketing, **then** select name and salary, **then** arrange by salary descending."

# %%
employees |>
  filter(department %in% c("Sales", "Marketing")) |>
  select(name, department, salary) |>
  arrange(desc(salary))

# %% [markdown]
# ## Practice Exercises
#
# Try these on your own using the `employees` data. Write your code in the empty cells below.
#
# **Exercise 1:** Find all employees older than 40. How many are there?

# %%
# Your code here

# %% [markdown]
# **Exercise 2:** What is the average age per department? Which department has the youngest average?

# %%
# Your code here

# %% [markdown]
# **Exercise 3:** Create a new column called `years_employed` that calculates how many years each person has been employed (hint: use `as.numeric(Sys.Date() - as.Date(hire_date)) / 365`). Then find the 5 longest-tenured employees.

# %%
# Your code here

# %% [markdown]
# **Exercise 4:** Which city has the most employees? Use `count()` (a shortcut for `group_by() |> summarize(n = n())`).

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Notebooks vs. Scripts
#
# So far you have been writing code in notebook cells — running them one at a time, seeing output inline, mixing code with explanations. This is ideal for exploration and analysis. But it is not the only way to run R.
#
# A **script** is a plain `.R` file that contains R code and nothing else — no cells, no markdown, no inline output. When you run a script, R executes every line from top to bottom and then exits. Scripts are the right choice when:
#
# - You need to **automate** something (run the same task every day, process a batch of files)
# - Your code is **finished and tested** — you no longer need to tweak it interactively
# - You want to **share a tool** that someone else can run with a single command
# - The task does not benefit from inline visualization or step-by-step exploration
#
# ### Creating a script from a notebook cell
#
# You can create an R script directly from a notebook cell using `writeLines()`:

# %%
writeLines(c(
  '# A simple R script',
  'name <- "World"',
  'message("Hello, ", name, "!")',
  'message("This is running as a script, not a notebook cell.")'
), "hello.R")

cat("Created hello.R\n")

# %% [markdown]
# Running that cell created a file called `hello.R` in the current folder. You can run it from within the notebook using `system()`:

# %%
system("Rscript hello.R")

# %% [markdown]
# ### Three ways to run an R script
#
# You just ran a script from inside a notebook using `system()`. But in practice you will usually run scripts outside of notebooks. Here are the three main ways:
#
# 1. **From the terminal.** Open a terminal (standalone or inside VS Code), make sure your environment is active, and run:
#    ```bash
#    Rscript hello.R
#    ```
#    `Rscript` is a command-line tool that comes with R — it runs a `.R` file from top to bottom and exits.
#
# 2. **From VS Code's editor.** Open the `.R` file in VS Code. With the R extension installed, click the **play button (▶)** in the top right corner or use the keyboard shortcut shown in the R extension to source the file.
#
# 3. **From VS Code's integrated terminal.** Open the terminal inside VS Code (`` Ctrl + ` ``), activate your environment if needed, and type `Rscript hello.R`. This is the same as option 1 but without leaving VS Code.
#
# ### When to use which
#
# | Use a **notebook** when... | Use a **script** when... |
# |----------------------------|--------------------------|
# | Exploring data for the first time | Automating a repeatable task |
# | Building and testing an analysis step by step | Running a pipeline on a schedule |
# | Creating visualizations inline | Processing files in batch |
# | Mixing code with written explanations | Building a command-line tool |
# | Sharing a narrative with results | Deploying code to a server |
#
# Many workflows start as notebooks and graduate to scripts. You might explore a dataset interactively in a notebook, figure out the right transformations, and then move the final version into a `.R` file that can run unattended.

# %% [markdown]
# ---
# ## Summary
#
# In this notebook you learned:
# - R basics: variables, types, arithmetic, vectors
# - Data frames: R's table structure
# - The tidyverse: a modern toolkit for data analysis
# - The pipe `|>`: chaining operations left to right
# - dplyr verbs: select, filter, mutate, arrange, summarize + group_by
#
# **Next up:** [02 - Introduction to Big Data Tools](02-big-data-intro.ipynb) — what they are and when you need them.
