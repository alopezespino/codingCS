# %% [markdown]
# # Python Fundamentals
#
# **What you'll learn:** The building blocks of Python — variables, data types, lists, dictionaries, loops, functions, and a first look at NumPy and pandas.
#
# **Prerequisites:** None. This is the starting point.
#
# **Why Python?** Python is one of the most popular programming languages for data analysis. It has a clean, readable syntax that reads almost like English, a massive ecosystem of data-science libraries, and is used by companies like Google, Netflix, and NASA.

# %% [markdown]
# ## 1. Variables and Assignment
#
# A **variable** is a name that stores a value. Think of it as a labeled box — you put something in, and you can refer to it later by its label.
#
# You create a variable with the `=` sign (called the **assignment operator**).

# %%
x = 5
name = "Alice"
temperature = 72.3

print(x)
print(name)
print(temperature)

# %% [markdown]
# You can change the value of a variable at any time by assigning a new value to it:

# %%
x = 5
print(x)

x = 10
print(x)

# %% [markdown]
# ## 2. Data Types
#
# Every value in Python has a **type** that determines what you can do with it. The four basic types are:
#
# | Type | What it is | Example |
# |------|------------|----------|
# | `int` | Whole number | `42` |
# | `float` | Decimal number | `3.14` |
# | `str` | Text (string) | `"hello"` |
# | `bool` | True or False | `True` |
#
# Use the `type()` function to check what type a value is:

# %%
print(type(42))
print(type(3.14))
print(type("hello"))
print(type(True))

# %%
age = 25
price = 9.99
city = "Chicago"
is_student = True

print(type(age))
print(type(price))
print(type(city))
print(type(is_student))

# %% [markdown]
# ## 3. Basic Arithmetic
#
# Python works like a calculator. Here are the main arithmetic operators:
#
# | Operator | Meaning | Example | Result |
# |----------|---------|---------|--------|
# | `+` | Addition | `3 + 2` | `5` |
# | `-` | Subtraction | `3 - 2` | `1` |
# | `*` | Multiplication | `3 * 2` | `6` |
# | `/` | Division | `7 / 2` | `3.5` |
# | `//` | Integer division | `7 // 2` | `3` |
# | `%` | Remainder (modulo) | `7 % 2` | `1` |
# | `**` | Exponent (power) | `3 ** 2` | `9` |

# %%
print(3 + 2)
print(10 - 4)
print(6 * 7)
print(15 / 4)
print(15 // 4)
print(15 % 4)
print(2 ** 10)

# %%
hours_worked = 40
hourly_rate = 25.50
weekly_pay = hours_worked * hourly_rate
print(f"Weekly pay: ${weekly_pay}")

# %% [markdown]
# ## 4. Strings
#
# A **string** is a sequence of characters (text). You create strings with quotes — single `'...'` or double `"..."` both work.
#
# **A note on comments:** From this point on, you will see lines starting with `#` in code cells. These are **comments** — Python ignores them completely. They exist only to help you (the reader) understand what the code is doing. You can also use `#` to temporarily disable a line of code without deleting it.

# %%
greeting = "Hello"
target = "World"

# Concatenation: joining strings with +
message = greeting + ", " + target + "!"
print(message)

# %% [markdown]
# **f-strings** (formatted strings) are the modern way to insert variables into text. Put an `f` before the opening quote and use `{variable_name}` inside:

# %%
name = "Alice"
age = 28
print(f"My name is {name} and I am {age} years old.")
print(f"Next year I will be {age + 1}.")

# %% [markdown]
# Strings have built-in **methods** — functions you call on the string with a dot:

# %%
text = "  Hello, World!  "

print(text.upper())        # ALL CAPS
print(text.lower())        # all lowercase
print(text.strip())        # remove leading/trailing whitespace
print(text.split(","))     # split into a list at each comma

# %% [markdown]
# ## 5. Lists
#
# A **list** is an ordered collection of items. Lists are one of the most useful data structures in Python.
#
# You create a list with square brackets `[]` and separate items with commas:

# %%
fruits = ["apple", "banana", "cherry"]
numbers = [10, 20, 30, 40, 50]
mixed = [1, "hello", 3.14, True]

print(fruits)
print(numbers)
print(mixed)

# %% [markdown]
# **Indexing:** Access individual items by position. Python counts from 0, not 1.
#
# ```
# Index:   0        1        2
# List:  ["apple", "banana", "cherry"]
# ```

# %%
print(fruits[0])    # first item
print(fruits[1])    # second item
print(fruits[-1])   # last item (negative index counts from the end)

# %% [markdown]
# **Slicing:** Get a sub-list with `[start:end]`. The start is included, the end is not.

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers[1:4])   # items at index 1, 2, 3
print(numbers[:3])    # first 3 items
print(numbers[2:])    # from index 2 to the end

# %% [markdown]
# **Modifying lists:**

# %%
fruits = ["apple", "banana", "cherry"]

fruits.append("date")       # add to the end
print(fruits)

print(len(fruits))          # how many items

# %% [markdown]
# ## 6. Dictionaries
#
# A **dictionary** stores data as **key-value pairs**. Think of it like a real dictionary: you look up a word (key) to find its definition (value).
#
# You create a dictionary with curly braces `{}`:

# %%
student = {
    "name": "Alice",
    "age": 22,
    "major": "Economics",
    "gpa": 3.8
}

print(student)

# %%
# Access a value by its key
print(student["name"])
print(student["gpa"])

# Add a new key-value pair
student["university"] = "Purdue"
print(student)

# %% [markdown]
# ## 7. Comparisons and Logic
#
# **Comparison operators** compare two values and return `True` or `False`:
#
# | Operator | Meaning |
# |----------|----------|
# | `==` | Equal to |
# | `!=` | Not equal to |
# | `<` | Less than |
# | `>` | Greater than |
# | `<=` | Less than or equal |
# | `>=` | Greater than or equal |

# %%
print(5 == 5)    # True
print(5 != 3)    # True
print(10 < 7)    # False
print(3 >= 3)    # True

# %% [markdown]
# **Logical operators** combine conditions:
#
# - `and` — both must be True
# - `or` — at least one must be True
# - `not` — flips True to False and vice versa

# %%
age = 25
has_id = True

print(age >= 21 and has_id)    # True — both conditions met
print(age < 18 or has_id)      # True — at least one is True
print(not has_id)              # False — flips True to False

# %% [markdown]
# ## 8. Conditional Statements (if / elif / else)
#
# Conditionals let your code make decisions. The structure is:
#
# ```python
# if condition:
#     # runs if condition is True
# elif another_condition:
#     # runs if the first was False and this one is True
# else:
#     # runs if none of the above were True
# ```
#
# **Important:** The indented block (4 spaces) is how Python knows what code belongs to each branch.

# %%
score = 85

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
else:
    print("F")

# %%
temperature = 35

if temperature > 100:
    print("Boiling!")
elif temperature > 75:
    print("It's hot.")
elif temperature > 50:
    print("Nice weather.")
else:
    print("It's cold!")

# %% [markdown]
# ## 9. Loops
#
# Loops let you repeat code. The most common is the **for loop**, which goes through each item in a sequence.

# %%
# Loop over a list
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(f"I like {fruit}")

# %% [markdown]
# The `range()` function generates a sequence of numbers. `range(5)` gives you 0, 1, 2, 3, 4:

# %%
for i in range(5):
    print(f"Step {i}")

# %%
# A practical example: summing a list of numbers
prices = [12.50, 8.99, 25.00, 3.75]
total = 0

for price in prices:
    total = total + price

print(f"Total: ${total:.2f}")

# %% [markdown]
# ## 10. Functions
#
# A **function** is a reusable block of code that performs a specific task. You define a function with the `def` keyword:
#
# ```python
# def function_name(parameters):
#     # code that runs when the function is called
#     return result
# ```

# %%
def greet(name):
    return f"Hello, {name}!"

message = greet("Alice")
print(message)
print(greet("Bob"))

# %%
def calculate_tax(price, tax_rate=0.07):
    """Calculate the total price including tax."""
    tax = price * tax_rate
    return price + tax

print(calculate_tax(100))          # uses default 7% rate
print(calculate_tax(100, 0.10))    # uses 10% rate

# %% [markdown]
# ## 11. Importing Libraries
#
# A **library** (also called a **package**) is a collection of pre-written code that adds new capabilities. Instead of writing everything from scratch, you import libraries that others have built.
#
# The `import` statement loads a library so you can use it:
#
# ```python
# import numpy as np      # import numpy, refer to it as "np" for short
# import pandas as pd     # import pandas, refer to it as "pd" for short
# ```
#
# The `as np` / `as pd` parts are standard short names that everyone uses.

# %% [markdown]
# ## 12. NumPy Basics
#
# **NumPy** (Numerical Python) is the foundation for numerical computing in Python. Its core feature is the **array** — a fast, efficient way to work with lists of numbers.

# %%
import numpy as np

# Create an array from a list
numbers = np.array([10, 20, 30, 40, 50])
print(numbers)
print(type(numbers))

# %% [markdown]
# The big advantage of NumPy arrays: you can do math on all elements at once (this is called **vectorized operations**):

# %%
numbers = np.array([10, 20, 30, 40, 50])

print(numbers * 2)       # multiply every element by 2
print(numbers + 100)     # add 100 to every element
print(numbers ** 2)      # square every element

# %%
# Useful array functions
print(f"Mean: {numbers.mean()}")
print(f"Sum: {numbers.sum()}")
print(f"Min: {numbers.min()}")
print(f"Max: {numbers.max()}")
print(f"Shape: {numbers.shape}")  # shape tells you the dimensions

# %% [markdown]
# ## 13. Pandas: Your Data Analysis Toolkit
#
# **pandas** is the go-to library for working with tabular data (rows and columns, like a spreadsheet). Its core object is the **DataFrame** — a table.
#
# Let's load a real dataset from a CSV file:

# %%
import pandas as pd

# Read a CSV file into a DataFrame
df = pd.read_csv("../data/employees.csv")

# View the first 5 rows
df.head()

# %%
# How many rows and columns?
print(f"Shape: {df.shape}")
print(f"That's {df.shape[0]} rows and {df.shape[1]} columns.")

# %%
# What are the column names and their types?
df.dtypes

# %%
# Summary statistics for numeric columns
df.describe()

# %% [markdown]
# ### Selecting columns
#
# Use square brackets with the column name to select a single column:

# %%
# Single column — returns a Series
salaries = df["salary"]
print(salaries.head())
print(f"\nAverage salary: ${salaries.mean():,.2f}")

# %%
# Multiple columns — returns a DataFrame
subset = df[["name", "department", "salary"]]
subset.head()

# %% [markdown]
# ### Filtering rows
#
# You can filter a DataFrame using a condition inside square brackets:

# %% [markdown]
# When you write `df["salary"] > 100000`, pandas compares every row's salary to 100,000 and produces a list of `True`/`False` values — one per row. This is called a **boolean mask**. When you put that mask inside square brackets — `df[df["salary"] > 100000]` — pandas keeps only the rows where the value is `True` and drops the rest.

# %%
# Employees with salary above 100,000
high_earners = df[df["salary"] > 100000]
print(f"Found {len(high_earners)} employees earning over $100k:")
high_earners[["name", "department", "salary"]]

# %%
# Combine conditions with & (and) or | (or)
engineering_senior = df[(df["department"] == "Engineering") & (df["age"] > 40)]
engineering_senior[["name", "department", "age", "salary"]]

# %% [markdown]
# ---
#
# ## Practice Exercises
#
# Try these on your own using the `employees.csv` dataset (already loaded as `df` above).
#
# ### Exercise 1
# Find the average salary for each department. *Hint: use `df.groupby("department")["salary"].mean()`*

# %%
# Your code here

# %% [markdown]
# ### Exercise 2
# How many employees are in each city? *Hint: use `df["city"].value_counts()`*

# %%
# Your code here

# %% [markdown]
# ### Exercise 3
# Find all employees hired after 2021 who work in the Sales department. How many are there? *Hint: you can compare dates as strings — `df["hire_date"] > "2021-01-01"`*

# %%
# Your code here

# %% [markdown]
# ---
#
# ## 14. Notebooks vs. Scripts
#
# So far you have been writing code in notebook cells — running them one at a time, seeing output inline, mixing code with explanations. This is ideal for exploration and analysis. But it is not the only way to run Python.
#
# A **script** is a plain `.py` file that contains Python code and nothing else — no cells, no markdown, no inline output. When you run a script, Python executes every line from top to bottom and then exits. Scripts are the right choice when:
#
# - You need to **automate** something (run the same task every day, process a batch of files)
# - Your code is **finished and tested** — you no longer need to tweak it interactively
# - You want to **share a tool** that someone else can run with a single command
# - The task does not benefit from inline visualization or step-by-step exploration
#
# You already used a script in this repo: `scripts/generate_large_data.py` generated your large dataset with one command. That task did not need a notebook — it just needed to run and produce a file.
#
# ### Creating a script from a notebook cell
#
# The `%%writefile` magic command writes the contents of a cell to a file instead of executing them. Try it:

# %%
# %%writefile hello.py
"""A simple Python script."""

name = "World"
print(f"Hello, {name}!")
print("This is running as a script, not a notebook cell.")

# %% [markdown]
# Running that cell created a file called `hello.py` in the current folder. You can verify it exists and then run it from within the notebook:

# %%
# !python hello.py

# %% [markdown]
# ### Three ways to run a Python script
#
# You just ran a script from inside a notebook using `!python`. But in practice you will usually run scripts outside of notebooks. Here are the three main ways:
#
# 1. **From the terminal.** Open a terminal (standalone or inside VS Code), make sure your environment is active, and run:
#    ```bash
#    python hello.py
#    ```
#
# 2. **From VS Code's editor.** Open the `.py` file in VS Code. Click the **play button (▶)** in the top right corner of the editor. This runs the script in the integrated terminal using the Python interpreter from your selected environment.
#
# 3. **From VS Code's integrated terminal.** Open the terminal inside VS Code (`` Ctrl + ` ``), activate your environment if needed, and type `python hello.py`. This is the same as option 1 but without leaving VS Code.
#
# ### When to use which
#
# | Use a **notebook** when... | Use a **script** when... |
# |----------------------------|--------------------------|
# | Exploring data for the first time | Automating a repeatable task |
# | Building and testing an analysis step by step | Running a pipeline on a schedule |
# | Creating visualizations inline | Processing files in batch |
# | Mixing code with written explanations | Building a command-line tool |
# | Sharing a narrative with results | Deploying code to a server |
#
# Many workflows start as notebooks and graduate to scripts. You might explore a dataset interactively in a notebook, figure out the right transformations, and then move the final version into a `.py` file that can run unattended.

# %% [markdown]
# ---
#
# **Next up:** [02 - Introduction to Big Data Tools](02-big-data-intro.ipynb) — learn why tools like PySpark, Dask, and DuckDB exist and when to use them.
